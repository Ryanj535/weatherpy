# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import openweathermapy as ow
import csv

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 623

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
settings = {"units": "imperial", "appid": api_key}
chara_data = ow.get_current(city, **settings)
chara_data
cloudiness = []
country = []
date = []
humidity = []
max_temp = []
wind_speed = []
lat_coord = []
lng_coord = []
count=0
set_num=1
for city in cities:
    count+=1
    try:
        city_data = ow.get_current(city, **settings)
        print(f'Processing Record {count} of Set {set_num} | {city}')
    except:
        print(f'City not found. Skipping...')
    if count==50: 
        count = 0
        set_num+=1
    cloudiness.append(city_data['clouds']['all'])
    country.append(city_data['sys']['country'])
    date.append(city_data['dt'])
    humidity.append(city_data['main']['humidity'])
    max_temp.append(city_data['main']['temp_max'])
    wind_speed.append(city_data['wind']['speed'])
    lat_coord.append(city_data['coord']['lat'])
    lng_coord.append(city_data['coord']['lon'])
# Out:
# Processing Record 1 of Set 1 | vaini
# Processing Record 2 of Set 1 | yashkul
# Processing Record 3 of Set 1 | valence
# Processing Record 4 of Set 1 | karsava
# Processing Record 5 of Set 1 | lovozero
# Processing Record 6 of Set 1 | khatanga
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | kapaa
# Processing Record 9 of Set 1 | port alfred
# Processing Record 10 of Set 1 | thompson
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | albany
# Processing Record 13 of Set 1 | dana point
# City not found. Skipping...
# Processing Record 15 of Set 1 | yaguajay
# Processing Record 16 of Set 1 | sinnamary
# Processing Record 17 of Set 1 | codrington
# Processing Record 18 of Set 1 | mataura
# City not found. Skipping...
# Processing Record 20 of Set 1 | mahebourg
# Processing Record 21 of Set 1 | atuona
# Processing Record 22 of Set 1 | qaanaaq
# Processing Record 23 of Set 1 | busselton
# Processing Record 24 of Set 1 | bluff
# Processing Record 25 of Set 1 | goderich
# Processing Record 26 of Set 1 | jamestown
# City not found. Skipping...
# Processing Record 28 of Set 1 | souillac
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 31 of Set 1 | aksarka
# Processing Record 32 of Set 1 | taganak
# Processing Record 33 of Set 1 | bar-le-duc
# Processing Record 34 of Set 1 | xinqing
# Processing Record 35 of Set 1 | east london
# Processing Record 36 of Set 1 | port elizabeth
# Processing Record 37 of Set 1 | ponta do sol
# Processing Record 38 of Set 1 | nome
# Processing Record 39 of Set 1 | hermanus
# Processing Record 40 of Set 1 | cape town
# Processing Record 41 of Set 1 | georgetown
# Processing Record 42 of Set 1 | castro
# Processing Record 43 of Set 1 | pevek
# Processing Record 44 of Set 1 | pastavy
# Processing Record 45 of Set 1 | moquegua
# Processing Record 46 of Set 1 | fortuna
# Processing Record 47 of Set 1 | avarua
# Processing Record 48 of Set 1 | hobart
# Processing Record 49 of Set 1 | ulaangom
# Processing Record 50 of Set 1 | longyearbyen
# Processing Record 1 of Set 2 | pisco
# Processing Record 2 of Set 2 | prince rupert
# Processing Record 3 of Set 2 | isangel
# City not found. Skipping...
# Processing Record 5 of Set 2 | nicoya
# Processing Record 6 of Set 2 | peniche
# Processing Record 7 of Set 2 | nanortalik
# Processing Record 8 of Set 2 | lompoc
# Processing Record 9 of Set 2 | lulea
# City not found. Skipping...
# Processing Record 11 of Set 2 | barrow
# Processing Record 12 of Set 2 | hithadhoo
# Processing Record 13 of Set 2 | ribeira grande
# Processing Record 14 of Set 2 | provideniya
# Processing Record 15 of Set 2 | yumen
# Processing Record 16 of Set 2 | outlook
# City not found. Skipping...
# Processing Record 18 of Set 2 | ostrovnoy
# Processing Record 19 of Set 2 | puerto ayora
# Processing Record 20 of Set 2 | constitucion
# Processing Record 21 of Set 2 | basoko
# Processing Record 22 of Set 2 | clyde river
# Processing Record 23 of Set 2 | fairbanks
# Processing Record 24 of Set 2 | san cristobal
# Processing Record 25 of Set 2 | kodiak
# City not found. Skipping...
# Processing Record 27 of Set 2 | balakhninskiy
# Processing Record 28 of Set 2 | necochea
# Processing Record 29 of Set 2 | yulara
# Processing Record 30 of Set 2 | yellowknife
# Processing Record 31 of Set 2 | krasnik
# Processing Record 32 of Set 2 | mozarlandia
# Processing Record 33 of Set 2 | unity
# City not found. Skipping...
# Processing Record 35 of Set 2 | hervey bay
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 38 of Set 2 | praia da vitoria
# Processing Record 39 of Set 2 | new norfolk
# Processing Record 40 of Set 2 | komsomolskiy
# Processing Record 41 of Set 2 | chokurdakh
# Processing Record 42 of Set 2 | saldanha
# Processing Record 43 of Set 2 | jalu
# Processing Record 44 of Set 2 | sola
# Processing Record 45 of Set 2 | hay river
# Processing Record 46 of Set 2 | margate
# Processing Record 47 of Set 2 | tuktoyaktuk
# Processing Record 48 of Set 2 | bojnurd
# Processing Record 49 of Set 2 | lucea
# Processing Record 50 of Set 2 | palmares do sul
# Processing Record 1 of Set 3 | nikolskoye
# Processing Record 2 of Set 3 | san quintin
# Processing Record 3 of Set 3 | bambous virieux
# Processing Record 4 of Set 3 | vardo
# Processing Record 5 of Set 3 | hobyo
# Processing Record 6 of Set 3 | quatre cocos
# Processing Record 7 of Set 3 | kendari
# Processing Record 8 of Set 3 | poum
# Processing Record 9 of Set 3 | winnemucca
# Processing Record 10 of Set 3 | kayes
# Processing Record 11 of Set 3 | namibe
# Processing Record 12 of Set 3 | broome
# Processing Record 13 of Set 3 | hilo
# City not found. Skipping...
# Processing Record 15 of Set 3 | faanui
# Processing Record 16 of Set 3 | kandrian
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 19 of Set 3 | archidona
# Processing Record 20 of Set 3 | andros town
# City not found. Skipping...
# Processing Record 22 of Set 3 | butaritari
# Processing Record 23 of Set 3 | pont-sainte-maxence
# Processing Record 24 of Set 3 | hofn
# Processing Record 25 of Set 3 | severo-kurilsk
# Processing Record 26 of Set 3 | bonavista
# Processing Record 27 of Set 3 | bredasdorp
# Processing Record 28 of Set 3 | mount gambier
# Processing Record 29 of Set 3 | lazaro cardenas
# Processing Record 30 of Set 3 | bethel
# Processing Record 31 of Set 3 | kavieng
# City not found. Skipping...
# Processing Record 33 of Set 3 | itarema
# Processing Record 34 of Set 3 | arraial do cabo
# Processing Record 35 of Set 3 | progreso
# Processing Record 36 of Set 3 | cuiluan
# City not found. Skipping...
# Processing Record 38 of Set 3 | hayden
# Processing Record 39 of Set 3 | rabo de peixe
# Processing Record 40 of Set 3 | nha trang
# Processing Record 41 of Set 3 | cidreira
# Processing Record 42 of Set 3 | plouzane
# Processing Record 43 of Set 3 | akureyri
# Processing Record 44 of Set 3 | igarka
# Processing Record 45 of Set 3 | puerto escondido
# Processing Record 46 of Set 3 | awjilah
# Processing Record 47 of Set 3 | shingu
# Processing Record 48 of Set 3 | yar-sale
# Processing Record 49 of Set 3 | khandyga
# Processing Record 50 of Set 3 | bubaque
# Processing Record 1 of Set 4 | novikovo
# City not found. Skipping...
# Processing Record 3 of Set 4 | bagdarin
# Processing Record 4 of Set 4 | srednekolymsk
# Processing Record 5 of Set 4 | kholodnyy
# Processing Record 6 of Set 4 | luderitz
# Processing Record 7 of Set 4 | braganca
# Processing Record 8 of Set 4 | tucuman
# Processing Record 9 of Set 4 | chuy
# Processing Record 10 of Set 4 | saint george
# Processing Record 11 of Set 4 | high level
# Processing Record 12 of Set 4 | aswan
# Processing Record 13 of Set 4 | port hawkesbury
# Processing Record 14 of Set 4 | kholmsk
# Processing Record 15 of Set 4 | iqaluit
# City not found. Skipping...
# Processing Record 17 of Set 4 | amapa
# Processing Record 18 of Set 4 | beringovskiy
# Processing Record 19 of Set 4 | kurilsk
# Processing Record 20 of Set 4 | urengoy
# Processing Record 21 of Set 4 | corinto
# Processing Record 22 of Set 4 | waynesville
# Processing Record 23 of Set 4 | villaviciosa
# Processing Record 24 of Set 4 | arman
# Processing Record 25 of Set 4 | ayagoz
# Processing Record 26 of Set 4 | zhigansk
# City not found. Skipping...
# Processing Record 28 of Set 4 | cockburn town
# Processing Record 29 of Set 4 | kaniama
# Processing Record 30 of Set 4 | diego de almagro
# Processing Record 31 of Set 4 | umm kaddadah
# Processing Record 32 of Set 4 | muroto
# Processing Record 33 of Set 4 | dikson
# Processing Record 34 of Set 4 | grand gaube
# Processing Record 35 of Set 4 | geraldton
# Processing Record 36 of Set 4 | pampa
# Processing Record 37 of Set 4 | makubetsu
# City not found. Skipping...
# Processing Record 39 of Set 4 | carnarvon
# Processing Record 40 of Set 4 | cayenne
# City not found. Skipping...
# Processing Record 42 of Set 4 | ancud
# Processing Record 43 of Set 4 | mar del plata
# Processing Record 44 of Set 4 | lagoa
# Processing Record 45 of Set 4 | tasiilaq
# City not found. Skipping...
# Processing Record 47 of Set 4 | xam nua
# Processing Record 48 of Set 4 | naples park
# Processing Record 49 of Set 4 | russell
# Processing Record 50 of Set 4 | richards bay
# Processing Record 1 of Set 5 | airai
# Processing Record 2 of Set 5 | evensk
# Processing Record 3 of Set 5 | tombouctou
# Processing Record 4 of Set 5 | huarmey
# Processing Record 5 of Set 5 | alofi
# Processing Record 6 of Set 5 | faya
# Processing Record 7 of Set 5 | punta arenas
# Processing Record 8 of Set 5 | talnakh
# Processing Record 9 of Set 5 | port hardy
# Processing Record 10 of Set 5 | los llanos de aridane
# City not found. Skipping...
# Processing Record 12 of Set 5 | vanavara
# Processing Record 13 of Set 5 | paamiut
# Processing Record 14 of Set 5 | saint-philippe
# Processing Record 15 of Set 5 | anyama
# Processing Record 16 of Set 5 | gornopravdinsk
# Processing Record 17 of Set 5 | belaya gora
# Processing Record 18 of Set 5 | kovur
# Processing Record 19 of Set 5 | atambua
# Processing Record 20 of Set 5 | viedma
# Processing Record 21 of Set 5 | victoria
# Processing Record 22 of Set 5 | laguna
# Processing Record 23 of Set 5 | cherskiy
# Processing Record 24 of Set 5 | baker city
# Processing Record 25 of Set 5 | kamaishi
# Processing Record 26 of Set 5 | eyl
# Processing Record 27 of Set 5 | zhob
# Processing Record 28 of Set 5 | shugurovo
# Processing Record 29 of Set 5 | mahibadhoo
# Processing Record 30 of Set 5 | wladyslawowo
# Processing Record 31 of Set 5 | mayskiy
# Processing Record 32 of Set 5 | toora-khem
# Processing Record 33 of Set 5 | padang
# City not found. Skipping...
# Processing Record 35 of Set 5 | lorengau
# Processing Record 36 of Set 5 | pangnirtung
# Processing Record 37 of Set 5 | berlevag
# Processing Record 38 of Set 5 | camopi
# Processing Record 39 of Set 5 | raduzhnyy
# Processing Record 40 of Set 5 | havre-saint-pierre
# Processing Record 41 of Set 5 | kruisfontein
# Processing Record 42 of Set 5 | opuwo
# Processing Record 43 of Set 5 | surok
# Processing Record 44 of Set 5 | bahia honda
# Processing Record 45 of Set 5 | santa isabel do rio negro
# Processing Record 46 of Set 5 | oktyabrskoye
# Processing Record 47 of Set 5 | lae
# Processing Record 48 of Set 5 | caibarien
# Processing Record 49 of Set 5 | kenora
# Processing Record 50 of Set 5 | madanapalle
# Processing Record 1 of Set 6 | flin flon
# City not found. Skipping...
# Processing Record 3 of Set 6 | grindavik
# Processing Record 4 of Set 6 | mizdah
# Processing Record 5 of Set 6 | zeya
# City not found. Skipping...
# Processing Record 7 of Set 6 | acapulco
# Processing Record 8 of Set 6 | yakovlevka
# Processing Record 9 of Set 6 | muros
# City not found. Skipping...
# Processing Record 11 of Set 6 | nueva loja
# Processing Record 12 of Set 6 | yelizavetino
# Processing Record 13 of Set 6 | klaksvik
# Processing Record 14 of Set 6 | posadas
# City not found. Skipping...
# Processing Record 16 of Set 6 | sorland
# Processing Record 17 of Set 6 | beloha
# Processing Record 18 of Set 6 | chifeng
# Processing Record 19 of Set 6 | princeton
# Processing Record 20 of Set 6 | nishihara
# Processing Record 21 of Set 6 | nargana
# Processing Record 22 of Set 6 | dukat
# City not found. Skipping...
# Processing Record 24 of Set 6 | humberto de campos
# Processing Record 25 of Set 6 | cabo san lucas
# Processing Record 26 of Set 6 | kihei
# Processing Record 27 of Set 6 | ilulissat
# Processing Record 28 of Set 6 | honningsvag
# Processing Record 29 of Set 6 | kaitangata
# Processing Record 30 of Set 6 | shiyan
# Processing Record 31 of Set 6 | moerai
# Processing Record 32 of Set 6 | galle
# Processing Record 33 of Set 6 | pochinok
# Processing Record 34 of Set 6 | champerico
# Processing Record 35 of Set 6 | coihaique
# Processing Record 36 of Set 6 | torbat-e jam
# Processing Record 37 of Set 6 | ostersund
# Processing Record 38 of Set 6 | summerland
# Processing Record 39 of Set 6 | mehamn
# Processing Record 40 of Set 6 | lata
# Processing Record 41 of Set 6 | klamath falls
# Processing Record 42 of Set 6 | kroonstad
# Processing Record 43 of Set 6 | chicama
# City not found. Skipping...
# Processing Record 45 of Set 6 | vagamo
# Processing Record 46 of Set 6 | saint-denis
# City not found. Skipping...
# Processing Record 48 of Set 6 | vao
# Processing Record 49 of Set 6 | parker
# Processing Record 50 of Set 6 | bako
# Processing Record 1 of Set 7 | ranong
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 4 of Set 7 | saint-pierre
# Processing Record 5 of Set 7 | howard springs
# Processing Record 6 of Set 7 | naron
# Processing Record 7 of Set 7 | ulagan
# City not found. Skipping...
# Processing Record 9 of Set 7 | mani
# Processing Record 10 of Set 7 | sao joao da barra
# Processing Record 11 of Set 7 | mahina
# Processing Record 12 of Set 7 | mnogovershinnyy
# City not found. Skipping...
# Processing Record 14 of Set 7 | bull savanna
# Processing Record 15 of Set 7 | dingle
# Processing Record 16 of Set 7 | bitung
# City not found. Skipping...
# Processing Record 18 of Set 7 | farrukhabad
# Processing Record 19 of Set 7 | esperance
# Processing Record 20 of Set 7 | muriwai beach
# City not found. Skipping...
# Processing Record 22 of Set 7 | ono
# Processing Record 23 of Set 7 | torbay
# Processing Record 24 of Set 7 | samarai
# City not found. Skipping...
# Processing Record 26 of Set 7 | port lincoln
# Processing Record 27 of Set 7 | harnosand
# Processing Record 28 of Set 7 | lavrentiya
# City not found. Skipping...
# Processing Record 30 of Set 7 | voi
# Processing Record 31 of Set 7 | talaya
# City not found. Skipping...
# Processing Record 33 of Set 7 | alexandria
# Processing Record 34 of Set 7 | avera
# Processing Record 35 of Set 7 | camacha
# Processing Record 36 of Set 7 | alyangula
# Processing Record 37 of Set 7 | sunrise manor
# Processing Record 38 of Set 7 | hermon
# Processing Record 39 of Set 7 | seoul
# City not found. Skipping...
# Processing Record 41 of Set 7 | swedru
# Processing Record 42 of Set 7 | upernavik
# Processing Record 43 of Set 7 | neiafu
# Processing Record 44 of Set 7 | tiznit
# Processing Record 45 of Set 7 | ingersoll
# Processing Record 46 of Set 7 | porbandar
# Processing Record 47 of Set 7 | namatanai
# Processing Record 48 of Set 7 | hanyang
# City not found. Skipping...
# Processing Record 50 of Set 7 | presidencia roque saenz pena
# Processing Record 1 of Set 8 | oktyabrskiy
# Processing Record 2 of Set 8 | loandjili
# Processing Record 3 of Set 8 | kirra
# Processing Record 4 of Set 8 | borogontsy
# Processing Record 5 of Set 8 | san vicente
# Processing Record 6 of Set 8 | salinopolis
# Processing Record 7 of Set 8 | edea
# Processing Record 8 of Set 8 | oranjemund
# Processing Record 9 of Set 8 | orlik
# Processing Record 10 of Set 8 | aklavik
# Processing Record 11 of Set 8 | southern pines
# Processing Record 12 of Set 8 | nyurba
# City not found. Skipping...
# Processing Record 14 of Set 8 | vila franca do campo
# Processing Record 15 of Set 8 | waipawa
# Processing Record 16 of Set 8 | saskylakh
# Processing Record 17 of Set 8 | pangody
# Processing Record 18 of Set 8 | kochi
# Processing Record 19 of Set 8 | bali chak
# Processing Record 20 of Set 8 | oum hadjer
# Processing Record 21 of Set 8 | santa isabel
# Processing Record 22 of Set 8 | harrismith
# Processing Record 23 of Set 8 | roald
# City not found. Skipping...
# Processing Record 25 of Set 8 | luanda
# Processing Record 26 of Set 8 | sadiqabad
# Processing Record 27 of Set 8 | ayan
# Processing Record 28 of Set 8 | narsaq
# Processing Record 29 of Set 8 | turkan
# Processing Record 30 of Set 8 | tikapur
# Processing Record 31 of Set 8 | noumea
# Processing Record 32 of Set 8 | bodden town
# Processing Record 33 of Set 8 | half moon bay
# Processing Record 34 of Set 8 | lodja
# Processing Record 35 of Set 8 | oistins
# Processing Record 36 of Set 8 | payakumbuh
# Processing Record 37 of Set 8 | arenapolis
# Processing Record 38 of Set 8 | worland
# Processing Record 39 of Set 8 | hambantota
# Processing Record 40 of Set 8 | bunia
# Processing Record 41 of Set 8 | marawi
# Processing Record 42 of Set 8 | marzuq
# Processing Record 43 of Set 8 | roatan
# Processing Record 44 of Set 8 | rabat
# Processing Record 45 of Set 8 | katherine
# Processing Record 46 of Set 8 | sisimiut
# Processing Record 47 of Set 8 | dombarovskiy
# Processing Record 48 of Set 8 | tiksi
# Processing Record 49 of Set 8 | newala
# Processing Record 50 of Set 8 | zlatoust
# Processing Record 1 of Set 9 | urucui
# Processing Record 2 of Set 9 | san patricio
# Processing Record 3 of Set 9 | chimbote
# Processing Record 4 of Set 9 | sault sainte marie
# Processing Record 5 of Set 9 | baruun-urt
# Processing Record 6 of Set 9 | nador
# Processing Record 7 of Set 9 | weligama
# Processing Record 8 of Set 9 | gravdal
# Processing Record 9 of Set 9 | cabedelo
# Processing Record 10 of Set 9 | kahului
# Processing Record 11 of Set 9 | amurzet
# Processing Record 12 of Set 9 | ibotirama
# Processing Record 13 of Set 9 | saint-francois
# Processing Record 14 of Set 9 | lakatoro
# Processing Record 15 of Set 9 | makat
# Processing Record 16 of Set 9 | talara
# Processing Record 17 of Set 9 | port hueneme
# Processing Record 18 of Set 9 | palmer
# Processing Record 19 of Set 9 | lima
# Processing Record 20 of Set 9 | manacapuru
# Processing Record 21 of Set 9 | chernyshevskiy
# City not found. Skipping...
# Processing Record 23 of Set 9 | truro
# City not found. Skipping...
# Processing Record 25 of Set 9 | makakilo city
# Processing Record 26 of Set 9 | kavaratti
# Processing Record 27 of Set 9 | hanna
# Processing Record 28 of Set 9 | tromso
# Processing Record 29 of Set 9 | boysun
# Processing Record 30 of Set 9 | wanaraja
# Processing Record 31 of Set 9 | emerald
# Processing Record 32 of Set 9 | celestun
# Processing Record 33 of Set 9 | vila velha
# Processing Record 34 of Set 9 | karonga
# Processing Record 35 of Set 9 | taguatinga
# Processing Record 36 of Set 9 | tarakan
# Processing Record 37 of Set 9 | pakxan
# Processing Record 38 of Set 9 | kinlochleven
# Processing Record 39 of Set 9 | palmeira
# Processing Record 40 of Set 9 | hernani
# Processing Record 41 of Set 9 | naze
# City not found. Skipping...
# Processing Record 43 of Set 9 | norman wells
# Processing Record 44 of Set 9 | zbiroh
# Processing Record 45 of Set 9 | sibu
# Processing Record 46 of Set 9 | khash
# Processing Record 47 of Set 9 | plettenberg bay
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 50 of Set 9 | hasaki
# Processing Record 1 of Set 10 | tuatapere
# Processing Record 2 of Set 10 | kulhudhuffushi
# Processing Record 3 of Set 10 | boffa
# City not found. Skipping...
# Processing Record 5 of Set 10 | abdanan
# Processing Record 6 of Set 10 | ivangorod
# Processing Record 7 of Set 10 | fort nelson
# Processing Record 8 of Set 10 | sari
# City not found. Skipping...
# Processing Record 10 of Set 10 | tulun
# Processing Record 11 of Set 10 | urucara
# Processing Record 12 of Set 10 | salalah
# City not found. Skipping...
# Processing Record 14 of Set 10 | westport
# Processing Record 15 of Set 10 | kiunga
# Processing Record 16 of Set 10 | smithers
# City not found. Skipping...
# Processing Record 18 of Set 10 | verkhnevilyuysk
# Processing Record 19 of Set 10 | paracuru
# Processing Record 20 of Set 10 | kirakira
# Processing Record 21 of Set 10 | kolarovo
# Processing Record 22 of Set 10 | sawakin
# Processing Record 23 of Set 10 | lebu
# Processing Record 24 of Set 10 | yabrud
# Processing Record 25 of Set 10 | ucluelet
# Processing Record 26 of Set 10 | watertown
# Processing Record 27 of Set 10 | calella
# Processing Record 28 of Set 10 | najran
# Processing Record 29 of Set 10 | socorro
# Processing Record 30 of Set 10 | maniitsoq
# Processing Record 31 of Set 10 | balaipungut
# Processing Record 32 of Set 10 | saint-paul
# Processing Record 33 of Set 10 | guerrero negro
# Processing Record 34 of Set 10 | vestmannaeyjar
# Processing Record 35 of Set 10 | ambilobe
# Processing Record 36 of Set 10 | tondela
# City not found. Skipping...
# Processing Record 38 of Set 10 | sohag
# Processing Record 39 of Set 10 | malpe
# Processing Record 40 of Set 10 | dixon
# Processing Record 41 of Set 10 | tabou
# City not found. Skipping...
# Processing Record 43 of Set 10 | atbasar
# Processing Record 44 of Set 10 | lomovka
# Processing Record 45 of Set 10 | batagay
# Processing Record 46 of Set 10 | sao filipe
# Processing Record 47 of Set 10 | baykit
# Processing Record 48 of Set 10 | labuhan
# Processing Record 49 of Set 10 | alugan
# Processing Record 50 of Set 10 | tautira
# Processing Record 1 of Set 11 | thessalon
# City not found. Skipping...
# Processing Record 3 of Set 11 | dong hoi
# Processing Record 4 of Set 11 | tadine
# Processing Record 5 of Set 11 | kirkcudbright
# Processing Record 6 of Set 11 | sterling
# Processing Record 7 of Set 11 | tifton
# Processing Record 8 of Set 11 | jaguey grande
# Processing Record 9 of Set 11 | pierre
# Processing Record 10 of Set 11 | brest
# Processing Record 11 of Set 11 | det udom
# Processing Record 12 of Set 11 | kenai
# Processing Record 13 of Set 11 | cururupu
# City not found. Skipping...
# Processing Record 15 of Set 11 | marolambo
# Processing Record 16 of Set 11 | sur
# Processing Record 17 of Set 11 | iquique
# Processing Record 18 of Set 11 | hienghene
# Processing Record 19 of Set 11 | road town
# Processing Record 20 of Set 11 | bathsheba
# Processing Record 21 of Set 11 | warrington
# Processing Record 22 of Set 11 | tyup
# Processing Record 23 of Set 11 | yamada
# Processing Record 24 of Set 11 | togur
# City not found. Skipping...
# Processing Record 26 of Set 11 | haines junction
# Processing Record 27 of Set 11 | touros
# Processing Record 28 of Set 11 | saint anthony
# City not found. Skipping...
# Processing Record 30 of Set 11 | ales
# Processing Record 31 of Set 11 | atikokan
# Processing Record 32 of Set 11 | nouadhibou
# Processing Record 33 of Set 11 | leningradskiy
# Processing Record 34 of Set 11 | karakol
# Processing Record 35 of Set 11 | kiama
# Processing Record 36 of Set 11 | karasjok
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 39 of Set 11 | san francisco
# Processing Record 40 of Set 11 | baoqing
# Processing Record 41 of Set 11 | karratha
# Processing Record 42 of Set 11 | forbesganj
# Processing Record 43 of Set 11 | barsi
# Processing Record 44 of Set 11 | rosetta
# Processing Record 45 of Set 11 | vanimo
# Processing Record 46 of Set 11 | juneau
# Processing Record 47 of Set 11 | waddan
# Processing Record 48 of Set 11 | husavik
# Processing Record 49 of Set 11 | puerto baquerizo moreno
# Processing Record 50 of Set 11 | mao
# Processing Record 1 of Set 12 | ikalamavony
# Processing Record 2 of Set 12 | praia
# Processing Record 3 of Set 12 | kijang
# Processing Record 4 of Set 12 | port-gentil
# City not found. Skipping...
# Processing Record 6 of Set 12 | katangli
# Processing Record 7 of Set 12 | nouakchott
# Processing Record 8 of Set 12 | mokobeng
# Processing Record 9 of Set 12 | hoi an
# Processing Record 10 of Set 12 | lander
# Processing Record 11 of Set 12 | hua hin
# Processing Record 12 of Set 12 | nusaybin
# Processing Record 13 of Set 12 | mildura
# Processing Record 14 of Set 12 | san ramon
# Processing Record 15 of Set 12 | yantzaza
# Processing Record 16 of Set 12 | sambava
# Processing Record 17 of Set 12 | matara
# Processing Record 18 of Set 12 | kushima
# Processing Record 19 of Set 12 | nakatsu
# Processing Record 20 of Set 12 | honggang
# Processing Record 21 of Set 12 | oytal
# Processing Record 22 of Set 12 | batemans bay
# Processing Record 23 of Set 12 | bima
# Processing Record 24 of Set 12 | komatipoort
# Processing Record 25 of Set 12 | terney
# Processing Record 26 of Set 12 | monte alegre
# Processing Record 27 of Set 12 | duldurga
# Processing Record 28 of Set 12 | vila do maio
# Processing Record 29 of Set 12 | nacimiento
# Processing Record 30 of Set 12 | wufeng
# Processing Record 31 of Set 12 | sao bartolomeu de messines
# Processing Record 32 of Set 12 | bonthe
# Processing Record 33 of Set 12 | listvyanka
# Processing Record 34 of Set 12 | dalbandin
# City not found. Skipping...
# Processing Record 36 of Set 12 | lufilufi
# Processing Record 37 of Set 12 | tandil
# Processing Record 38 of Set 12 | bairnsdale
# Processing Record 39 of Set 12 | morondava
# Processing Record 40 of Set 12 | paramonga
# Processing Record 41 of Set 12 | banita
# Processing Record 42 of Set 12 | saint-louis
# Processing Record 43 of Set 12 | krabi
# Processing Record 44 of Set 12 | gloversville
# Processing Record 45 of Set 12 | kieta
# Processing Record 46 of Set 12 | baculin
# Processing Record 47 of Set 12 | shimoda
# Processing Record 48 of Set 12 | hami
# Processing Record 49 of Set 12 | pismo beach
# Processing Record 50 of Set 12 | campbell river
# Processing Record 1 of Set 13 | waingapu
# Processing Record 2 of Set 13 | ishige
# Processing Record 3 of Set 13 | riyadh
# Processing Record 4 of Set 13 | polkowice
# Processing Record 5 of Set 13 | hualmay
# Processing Record 6 of Set 13 | portree
# Processing Record 7 of Set 13 | rosetown
# Processing Record 8 of Set 13 | eldama ravine
# Processing Record 9 of Set 13 | gamboma
# Processing Record 10 of Set 13 | ippy
# Processing Record 11 of Set 13 | perpignan
# Processing Record 12 of Set 13 | belyy yar
# Processing Record 13 of Set 13 | okhotsk
# Processing Record 14 of Set 13 | carutapera
# Processing Record 15 of Set 13 | meulaboh
# Processing Record 16 of Set 13 | marsa matruh
# City not found. Skipping...
# Processing Record 18 of Set 13 | kaeo
# Processing Record 19 of Set 13 | dongsheng
# Processing Record 20 of Set 13 | bada
# City not found. Skipping...
# Processing Record 22 of Set 13 | ulundi
# Processing Record 23 of Set 13 | wangqing

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_df = pd.DataFrame({"City":cities,
                        "Cloudiness":cloudiness,
                        "Country":country,
                        "Date":date,
                        "Humidity":humidity,
                        "Lat":lat_coord,
                        "Lng":lng_coord,
                        "Max Temp":max_temp,
                        "Wind Speed":wind_speed})
city_df.to_csv('..\city_data.csv',index=False)

# %%
city_df.head()
# Out:
#        City  Cloudiness Country        Date  Humidity    Lat    Lng  Max Temp  \
# 0     vaini           0      IN  1550952501        65  15.34  74.49     66.13
# 1   yashkul          92      RU  1550952744        90  46.17  45.34     32.38
# 2   valence           0      FR  1550950200        75  44.93   4.89     42.80
# 3   karsava          92      LV  1550952744        94  56.78  27.69     33.23
# 4  lovozero          80      RU  1550952744       100  68.01  35.02     29.86
#
#    Wind Speed
# 0        2.37
# 1        9.42
# 2        3.36
# 3       13.78
# 4        6.85

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
